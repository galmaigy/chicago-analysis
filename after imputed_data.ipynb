# %%
import pandas as pd
df = pd.read_csv('data/imputed_data.csv',index_col=None)
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322004 entries, 0 to 322003
# Data columns (total 16 columns):
# Unnamed: 0            322004 non-null int64
# sp_lim                322004 non-null int64
# road                  322004 non-null object
# weather               322004 non-null object
# light                 322004 non-null object
# crash                 322004 non-null int64
# weekday               322004 non-null int64
# report_type           322004 non-null object
# num_units             322004 non-null float64
# device                322004 non-null object
# month                 322004 non-null int64
# year                  322004 non-null int64
# damage                322004 non-null object
# street_direction      322004 non-null object
# beat_of_occurrence    322004 non-null float64
# binned_speed          322004 non-null object
# dtypes: float64(2), int64(6), object(8)
# memory usage: 39.3+ MB
# ...

# %%
# missing data %
row, column = df.shape
round(((row - df.isnull().sum())/ row) * 100)
# Out:
# Unnamed: 0            100.0
# sp_lim                100.0
# road                  100.0
# weather               100.0
# light                 100.0
# crash                 100.0
# weekday               100.0
# report_type           100.0
# num_units             100.0
# device                100.0
# month                 100.0
# year                  100.0
# damage                100.0
# street_direction      100.0
# beat_of_occurrence    100.0
# binned_speed          100.0
# dtype: float64
